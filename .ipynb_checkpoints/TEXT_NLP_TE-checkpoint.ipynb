# %%
from bs4 import BeautifulSoup
import requests
import re
import csv
import pandas as pd
import numpy as np
import nltk
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp
import math

import string, unicodedata
#import contractions
#import inflect

#from nltk.corpus import stopwords
from nltk.stem import LancasterStemmer, WordNetLemmatizer

# %%
pd.set_option('display.max_columns', None)

# %%
page=requests.get("http://www.dailymail.co.uk/sport/index.html")

# %%
soup=BeautifulSoup(page.content, 'html.parser')
links=[a['href'].split('#')[0] for a in soup.find_all('a',attrs={'href':re.compile("^http://www.dailymail.co.uk/sport")})]

# %%
len(links)
# Out:
# 109

# %%
sportsarticles=[]

for link in links:
    body=requests.get(link)
    article=BeautifulSoup(body.content,'html.parser')
    paras=article.find_all('p',class_="mol-para-with-font")
    if paras:
        one=[]
        for text in paras:
            one.append(text.get_text())
    sportsarticles.append(one)

# %%
#removing nested list, converting each article as a big string instead
newlist=[]
for a in sportsarticles:
    b= ' '.join(a)
    newlist.append(b)

# %%
#removing duplicate articles
final_list = []
for num in newlist:
    if num not in final_list:
        final_list.append(num)

# %%
with open("articles6Aug.csv", "w") as output:
    writer = csv.writer(output, lineterminator='\n')
    for val in final_list:
        writer.writerow([val])

# %%
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('universal_tagset')
nltk.download('maxent_ne_chunker')
nltk.download('words')
nltk.download('vader_lexicon')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\rajat13440\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\rajat13440\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     C:\Users\rajat13440\AppData\Roaming\nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\rajat13440\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\rajat13440\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\rajat13440\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rajat13440\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\rajat13440\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.
# True

# %%
articles=pd.DataFrame({"articles":final_list})

# %%
articles["Tokens"]=articles["articles"].apply(lambda x:nltk.word_tokenize(str(x)))

# %%
articles["MsgSentenceTokens"]=articles["articles"].apply(lambda x:nltk.sent_tokenize(str(x)))

# %%
def remove_non_ascii(words):
    """Remove non-ASCII characters from list of tokenized words"""
    new_words = []
    for word in words:
        new_word = unicodedata.normalize('NFKD', word).encode('ascii', 'ignore').decode('utf-8', 'ignore')
        new_words.append(new_word)
    return new_words

# %%
def remove_stopwords(words):
    """Remove stop words from list of tokenized words"""
    new_words = []
    for word in words:
        if word not in nltk.corpus.stopwords.words('english'):
            new_words.append(word)
    return new_words

# %%
def lower(x):
    norm=[word.lower() for word in x]
    return norm

# %%
def remove_punctuation(words):
    """Remove punctuation from list of tokenized words"""
    new_words = []
    for word in words:
        new_word = re.sub(r'[^\w\s]', '', word)
        if new_word != '':
            new_words.append(new_word)
    return new_words

# %%
def normalize(x):
    x1=lower(x)
    x2=remove_punctuation(x1)
    x3=remove_non_ascii(x2)
    x4=remove_stopwords(x3)
    return x4

# %%
articles["NormTokens"]=articles["Tokens"].apply(lambda x: normalize(x))

# %%
articles["POS_Msg"]=articles["NormTokens"].apply(lambda x:nltk.pos_tag(x))

# %%
articles["POS_Msg_Uni"]=articles["NormTokens"].apply(lambda x:nltk.pos_tag(x,tagset='universal'))

# %%
def noun_POS(x):
    words=nltk.pos_tag(x,tagset='universal')
    mw= [word[0] for word in words if word[1]=='NOUN' or word[1]=='VERB']
    return mw

# %%
articles["POS_Msg_2"]=articles["NormTokens"].apply(lambda x:noun_POS(x))

# %%
def chunkMsg(x):
    entities=nltk.chunk.ne_chunk(x)
    return x

# %%
articles["Chunked"] = articles["POS_Msg"].apply(lambda x: chunkMsg(x))

# %%
len(articles["Chunked"][0])
# Out:
# 403

# %%
len(articles["POS_Msg"][0])
# Out:
# 403

# %%
articles.drop(["POS_Msg_2","NormTokensNew","POS_Msg_Uni","Chunked"],axis=1,inplace=True)

# %%
articles.head()
# Out:
#                                             articles  \
# 0  No wonder Jose Mourinho is worried about the s...
# 1  Premier League clubs are facing a last minute ...
# 2  The new Premier League season has finally arri...
# 3  Manchester United have held talks with Bayern ...
# 4  Everton have agreed a £28.5million fee for Bar...
#
#                                               Tokens  \
# 0  [No, wonder, Jose, Mourinho, is, worried, abou...
# 1  [Premier, League, clubs, are, facing, a, last,...
# 2  [The, new, Premier, League, season, has, final...
# 3  [Manchester, United, have, held, talks, with, ...
# 4  [Everton, have, agreed, a, £28.5million, fee, ...
#
#                                    MsgSentenceTokens  \
# 0  [No wonder Jose Mourinho is worried about the ...
# 1  [Premier League clubs are facing a last minute...
# 2  [The new Premier League season has finally arr...
# 3  [Manchester United have held talks with Bayern...
# 4  [Everton have agreed a £28.5million fee for Ba...
#
#                                           NormTokens  \
# 0  [wonder, jose, mourinho, worried, start, new, ...
# 1  [premier, league, clubs, facing, last, minute,...
# 2  [new, premier, league, season, finally, arrive...
# 3  [manchester, united, held, talks, bayern, muni...
# 4  [everton, agreed, 285million, fee, barcelona, ...
#
#                                              POS_Msg  Sentiments  Sentiments2
# 0  [(wonder, NN), (jose, NN), (mourinho, NN), (wo...         1.0         -1.0
# 1  [(premier, JJR), (league, NN), (clubs, NNS), (...        -1.0         -1.0
# 2  [(new, JJ), (premier, NN), (league, NN), (seas...         0.0         -1.0
# 3  [(manchester, NN), (united, VBD), (held, VBD),...        -1.0          1.0
# 4  [(everton, NNS), (agreed, VBD), (285million, C...         1.0          1.0

# %%
sentence=articles["POS_Msg"][0]

# %%
grammar = "NP: {<DT>?<JJ>*<NN>}"

# %%
cp = nltk.RegexpParser(grammar)

# %%
result = cp.parse(sentence)

# %%
print(result)
# Out:
# (S
#   (NP no/DT wonder/NN)
#   (NP jose/NN)
#   (NP mourinho/NN)
#   is/VBZ
#   worried/VBN
#   about/IN
#   (NP the/DT start/NN)
#   of/IN
#   (NP the/DT new/JJ season/NN)
#   ./.
#   four/CD
#   days/NNS
#   to/TO
#   go/VB
#   until/IN
#   it/PRP
#   kicks/VBZ
#   off/RP
#   at/IN
#   (NP old/JJ trafford/NN)
#   and/CC
#   he/PRP
#   is/VBZ
#   still/RB
#   waiting/VBG
#   for/IN
#   (NP the/DT real/JJ manchester/NN)
#   united/VBD
#   to/TO
#   turn/VB
#   up/RP
#   ./.
#   this/DT
#   has/VBZ
#   been/VBN
#   a/DT
#   strange/JJ
#   ,/,
#   disjointed/VBD
#   few/JJ
#   weeks/NNS
#   for/IN
#   (NP mourinho/NN)
#   and/CC
#   his/PRP$
#   players/NNS
#   ,/,
#   and/CC
#   it/PRP
#   showed/VBD
#   as/IN
#   they/PRP
#   completed/VBD
#   their/PRP$
#   (NP pre-season/NN)
#   on/IN
#   (NP a/DT muggy/JJ night/NN)
#   in/IN
#   (NP munich/NN)
#   ./.
#   on/IN
#   (NP this/DT evidence/NN)
#   ,/,
#   whatever/WDT
#   (NP team/NN)
#   united/VBD
#   put/VBD
#   out/RP
#   on/IN
#   (NP friday/JJ night/NN)
#   will/MD
#   struggle/VB
#   to/TO
#   overcome/VB
#   (NP leicester/NN)
#   never/RB
#   mind/VBP
#   challenge/JJ
#   manchester/NNP
#   (NP city/NN)
#   's/POS
#   (NP dominance/NN)
#   of/IN
#   (NP the/DT premier/NN)
#   (NP league/NN)
#   ./.
#   bayern/JJ
#   munich/JJ
#   (/(
#   3-4-3/JJ
#   )/)
#   :/:
#   (NP neuer/NN)
#   ;/:
#   kimmich/CC
#   (/(
#   rudy/VB
#   72/CD
#   )/)
#   ,/,
#   (NP sule/NN)
#   ,/,
#   hummels/NNS
#   (/(
#   boateng/IN
#   46/CD
#   )/)
#   ,/,
#   alaba/FW
#   (/(
#   bernat/IN
#   56/CD
#   )/)
#   ;/:
#   martinez/CC
#   ;/:
#   (NP robben/NN)
#   ,/,
#   (NP muller/NN)
#   ,/,
#   (NP thiago/NN)
#   (/(
#   rafinha/VB
#   60/CD
#   )/)
#   ,/,
#   (NP ribery/NN)
#   ;/:
#   (NP gnabry/NN)
#   ./.
#   subs/NNS
#   :/:
#   ulreich/JJ
#   ,/,
#   (NP hoffmann/NN)
#   ,/,
#   (NP lewandowski/NN)
#   ,/,
#   (NP boateng/NN)
#   ,/,
#   (NP goretzka/NN)
#   ,/,
#   (NP coman/NN)
#   ,/,
#   (NP mai/NN)
#   ,/,
#   (NP zylla/NN)
#   ,/,
#   (NP franzke/NN)
#   ./.
#   booked/VBN
#   :/:
#   (NP boateng/JJ scorer/NN)
#   :/:
#   (NP martinez/NN)
#   59/CD
#   (NP man/NN)
#   (NP utd/NN)
#   (/(
#   4-3-3/JJ
#   )/)
#   :/:
#   de/FW
#   gea/FW
#   (/(
#   grant/VB
#   78/CD
#   )/)
#   ;/:
#   darmian/JJ
#   (/(
#   jones/NNS
#   65/CD
#   )/)
#   ,/,
#   bailly/RB
#   (/(
#   smalling/VBG
#   51/CD
#   )/)
#   ,/,
#   lindelof/FW
#   (/(
#   tuanzebe/IN
#   78/CD
#   )/)
#   ,/,
#   shaw/FW
#   (/(
#   mitchell/VB
#   78/CD
#   )/)
#   ;/:
#   (NP herrera/NN)
#   (/(
#   garner/$
#   81/CD
#   )/)
#   ,/,
#   (NP pereira/NN)
#   ,/,
#   fred/VBN
#   (/(
#   chong/JJ
#   78/CD
#   )/)
#   ;/:
#   mata/NNS
#   (/(
#   mctominay/VB
#   65/CD
#   )/)
#   ,/,
#   (NP rashford/NN)
#   (/(
#   fosu-mensah/JJ
#   65/CD
#   )/)
#   ,/,
#   sanchez/UH
#   ./.
#   subs/NNS
#   :/:
#   (NP greenwood/NN)
#   ./.
#   (NP referee/NN)
#   :/:
#   (NP robert/NN)
#   (NP hartmann/NN)
#   after/IN
#   (NP city/NN)
#   gave/VBD
#   (NP another/DT demonstration/NN)
#   of/IN
#   what/WP
#   they/PRP
#   can/MD
#   do/VB
#   at/IN
#   (NP wembley/NN)
#   ,/,
#   united/JJ
#   looked/VBD
#   (NP every/DT bit/NN)
#   (NP a/DT team/NN)
#   that/WDT
#   is/VBZ
#   coming/VBG
#   together/RB
#   in/IN
#   drips/NNS
#   and/CC
#   (NP drabs/NN)
#   ./.
#   (NP marcus/NN)
#   (NP rashford/NN)
#   returned/VBD
#   for/IN
#   more/JJR
#   than/IN
#   (NP an/DT hour/NN)
#   here/RB
#   ,/,
#   officially/RB
#   inheriting/VBG
#   (NP the/DT no.10/JJ shirt/NN)
#   vacated/VBN
#   by/IN
#   (NP zlatan/NN)
#   (NP ibrahimovic/NN)
#   ,/,
#   while/IN
#   phil/JJ
#   jones/NNS
#   and/CC
#   (NP victor/NN)
#   (NP lindelof/NN)
#   also/RB
#   played/VBD
#   for/IN
#   (NP the/DT first/JJ time/NN)
#   since/IN
#   (NP the/DT world/NN)
#   (NP cup/NN)
#   ./.
#   but/CC
#   there/EX
#   was/VBD
#   still/RB
#   (NP no/DT paul/NN)
#   (NP pogba/NN)
#   ,/,
#   (NP no/DT romelu/NN)
#   (NP lukaku/NN)
#   ,/,
#   (NP no/DT jesse/NN)
#   lingard/RB
#   ,/,
#   (NP no/DT ashley/NN)
#   young/JJ
#   and/CC
#   (NP no/DT marouane/NN)
#   (NP fellaini/NN)
#   ./.
#   nemanja/CC
#   matic/JJ
#   and/CC
#   (NP antonio/JJ valencia/NN)
#   are/VBP
#   injured/VBN
#   ./.
#   anthony/JJ
#   martial/JJ
#   and/CC
#   (NP marcos/JJ rojo/NN)
#   were/VBD
#   left/VBN
#   at/IN
#   (NP home/NN)
#   when/WRB
#   united/JJ
#   flew/VBD
#   to/TO
#   germany/VB
#   ,/,
#   casting/VBG
#   (NP further/JJ doubt/NN)
#   over/IN
#   their/PRP$
#   futures/NNS
#   at/IN
#   (NP old/JJ trafford/NN)
#   ,/,
#   and/CC
#   eric/JJ
#   bailly/RB
#   limped/VBD
#   off/RP
#   early/JJ
#   in/IN
#   (NP the/DT second/JJ half/NN)
#   ./.
#   (NP a/DT new/JJ centre-half/NN)
#   remains/VBZ
#   (NP the/DT priority/NN)
#   and/CC
#   (NP mourinho/NN)
#   is/VBZ
#   banking/VBG
#   on/IN
#   (NP united/JJ chief/JJ ed/NN)
#   (NP woodward/NN)
#   delivering/VBG
#   one/CD
#   ./.
#   united/VBN
#   were/VBD
#   reported/VBN
#   to/TO
#   have/VB
#   stepped/VBN
#   up/RP
#   their/PRP$
#   (NP interest/NN)
#   in/IN
#   (NP harry/NN)
#   (NP maguire/NN)
#   with/IN
#   (NP a/DT £75million/NN)
#   (NP bid/NN)
#   on/IN
#   (NP sunday/JJ night/NN)
#   as/IN
#   (NP leicester/NN)
#   continue/VBP
#   to/TO
#   resist/VB
#   ./.
#   it/PRP
#   's/VBZ
#   understood/JJ
#   that/IN
#   (NP jerome/JJ boateng/NN)
#   –/VBD
#   (NP a/DT half-time/JJ substitute/NN)
#   for/IN
#   (NP bayern/NN)
#   here/RB
#   –/NNP
#   is/VBZ
#   emerging/VBG
#   as/IN
#   (NP another/DT strong/JJ possibility/NN)
#   even/RB
#   though/IN
#   he/PRP
#   would/MD
#   cost/VB
#   £50m/NNP
#   and/CC
#   turns/VBZ
#   30/CD
#   (NP next/JJ month/NN)
#   ./.
#   asked/VBD
#   about/IN
#   (NP boateng/NN)
#   ,/,
#   (NP mourinho/NN)
#   said/VBD
#   :/:
#   'my/CD
#   (NP ceo/NN)
#   knows/VBZ
#   what/WP
#   (NP i/NN)
#   want/VBP
#   for/IN
#   quite/RB
#   (NP a/DT long/JJ time/NN)
#   ,/,
#   i/RB
#   know/VBP
#   he/PRP
#   tries/VBZ
#   to/TO
#   do/VB
#   the/DT
#   best/JJS
#   for/IN
#   me/PRP
#   and/CC
#   i/VB
#   still/RB
#   have/VBP
#   a/DT
#   few/JJ
#   days/NNS
#   to/TO
#   wait/VB
#   to/TO
#   see/VB
#   what/WP
#   happens/VBZ
#   ./.
#   '/''
#   otherwise/RB
#   ,/,
#   (NP the/DT united/JJ boss/NN)
#   is/VBZ
#   preparing/VBG
#   to/TO
#   make/VB
#   the/DT
#   most/JJS
#   out/IN
#   of/IN
#   the/DT
#   players/NNS
#   he/PRP
#   has/VBZ
#   available/JJ
#   against/IN
#   (NP leicester/NN)
#   ./.
#   'we/CC
#   were/VBD
#   unlucky/JJ
#   to/TO
#   get/VB
#   (NP the/DT friday/JJ game/NN)
#   so/RB
#   monday/RB
#   ,/,
#   (NP tuesday/NN)
#   ,/,
#   (NP wednesday/NN)
#   ,/,
#   (NP thursday/NN)
#   is/VBZ
#   not/RB
#   enough/RB
#   ,/,
#   '/''
#   he/PRP
#   added/VBD
#   ./.
#   'we/NNS
#   have/VBP
#   to/TO
#   organise/VB
#   (NP the/DT week/NN)
#   in/IN
#   (NP a/DT way/NN)
#   that/IN
#   we/PRP
#   can/MD
#   arrive/VB
#   fresh/JJ
#   for/IN
#   (NP friday/NN)
#   because/IN
#   (NP friday/NN)
#   starts/VBZ
#   (NP the/DT premier/NN)
#   (NP league/NN)
#   and/CC
#   we/PRP
#   play/VBP
#   for/IN
#   points/NNS
#   and/CC
#   (NP friday/NN)
#   is/VBZ
#   the/DT
#   players/NNS
#   we/PRP
#   have/VBP
#   ./.
#   'there/EX
#   is/VBZ
#   (NP no/DT time/NN)
#   to/TO
#   cry/VB
#   for/IN
#   the/DT
#   players/NNS
#   that/WDT
#   are/VBP
#   not/RB
#   going/VBG
#   to/TO
#   be/VB
#   ./.
#   on/IN
#   (NP friday/NN)
#   we/PRP
#   go/VBP
#   with/IN
#   the/DT
#   best/JJS
#   (NP possible/JJ team/NN)
#   ./.
#   '/''
#   (NP united/JJ look/NN)
#   (NP anything/NN)
#   but/CC
#   (NP the/DT finished/JJ article/NN)
#   and/CC
#   it/PRP
#   's/VBZ
#   hard/JJ
#   to/TO
#   see/VB
#   how/WRB
#   they/PRP
#   can/MD
#   click/VB
#   into/IN
#   (NP gear/NN)
#   in/IN
#   four/CD
#   days/NNS
#   after/IN
#   such/JJ
#   (NP a/DT fragmented/JJ preparation/NN)
#   ./.
#   they/PRP
#   were/VBD
#   under/IN
#   (NP the/DT cosh/NN)
#   throughout/IN
#   here/RB
#   and/CC
#   david/VB
#   de/FW
#   gea/FW
#   made/VBD
#   first/JJ
#   half/JJ
#   saves/NNS
#   from/IN
#   (NP thiago/NN)
#   (NP alcantara/NN)
#   and/CC
#   (NP serge/NN)
#   (NP gnabry/NN)
#   ./.
#   however/RB
#   ,/,
#   he/PRP
#   was/VBD
#   beaten/VBN
#   in/IN
#   the/DT
#   59th/CD
#   (NP minute/NN)
#   when/WRB
#   (NP javi/NN)
#   (NP martinez/NN)
#   rose/VBD
#   to/TO
#   score/VB
#   with/IN
#   a/DT
#   glancing/VBG
#   (NP header/NN)
#   from/IN
#   (NP thiago/NN)
#   's/POS
#   (NP corner/NN)
#   ,/,
#   (NP a/DT timely/JJ reminder/NN)
#   perhaps/RB
#   of/IN
#   united/JJ
#   's/POS
#   (NP need/NN)
#   for/IN
#   (NP an/DT upgrade/NN)
#   in/IN
#   (NP central/JJ defence/NN)
#   ./.
#   (NP manuel/NN)
#   (NP neuer/NN)
#   did/VBD
#   not/RB
#   have/VB
#   (NP a/DT single/JJ save/NN)
#   to/TO
#   make/VB
#   and/CC
#   mourinho/VB
#   ended/VBD
#   (NP the/DT game/NN)
#   by/IN
#   sending/VBG
#   on/IN
#   the/DT
#   kids/NNS
#   and/CC
#   (NP third-choice/JJ keeper/NN)
#   (NP lee/NN)
#   (NP grant/NN)
#   ./.
#   maybe/RB
#   it/PRP
#   was/VBD
#   (NP a/DT message/NN)
#   to/TO
#   woodward/VB
#   ./.
#   their/PRP$
#   (NP strained/JJ relationship/NN)
#   could/MD
#   deteriorate/VB
#   even/RB
#   further/RB
#   if/IN
#   there/EX
#   is/VBZ
#   n't/RB
#   (NP a/DT new/JJ addition/NN)
#   through/IN
#   (NP the/DT door/NN)
#   by/IN
#   5pm/CD
#   on/IN
#   (NP thursday/NN)
#   ./.
#   (NP peter/NN)
#   (NP kenyon/NN)
#   ,/,
#   the/DT
#   former/JJ
#   united/JJ
#   and/CC
#   (NP chelsea/NN)
#   (NP chief/JJ executive/NN)
#   who/WP
#   played/VBD
#   (NP a/DT key/JJ role/NN)
#   in/IN
#   (NP mourinho/NN)
#   's/POS
#   (NP appointment/NN)
#   at/IN
#   (NP stamford/NN)
#   (NP bridge/NN)
#   in/IN
#   2004/CD
#   ,/,
#   has/VBZ
#   been/VBN
#   there/EX
#   before/IN
#   and/CC
#   claimed/VBD
#   on/IN
#   (NP sunday/NN)
#   that/IN
#   (NP the/DT 55-year-old/JJ portuguese/JJ coach/NN)
#   can/MD
#   still/RB
#   make/VB
#   it/PRP
#   work/VB
#   ./.
#   but/CC
#   he/PRP
#   warned/VBD
#   :/:
#   'united/VBN
#   is/VBZ
#   bigger/JJR
#   than/IN
#   (NP anybody/NN)
#   ,/,
#   bigger/JJR
#   than/IN
#   any/DT
#   individual/JJ
#   and/CC
#   that/DT
#   's/VBZ
#   always/RB
#   been/VBN
#   (NP the/DT mantra/NN)
#   ./.
#   '/'')

# %%
result.draw()

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
sid = SentimentIntensityAnalyzer()
pos_word_list=[]
neg_word_list=[]
neu_word_list=[]

# %%
def GetSentiment(text):
    temp=[]
    ncount=0
    pcount=0
    for word in text:
    
        if (sid.polarity_scores(word)['compound']) >= 0.5:
            pcount+=1
            if word not in pos_word_list:
                pos_word_list.append(word)
        elif (sid.polarity_scores(word)['compound']) <= -0.5:
            ncount+=1
            if word not in neg_word_list:
                neg_word_list.append(word)
        else:
            if word not in neu_word_list: 
                neu_word_list.append(word)
    if(pcount>0 and ncount==0):
        temp.append(1)
    elif(ncount%2>0):
        temp.append(-1)
    elif(ncount%2==0 and ncount==0):
        temp.append(1)
    else:
        temp.append(0)            
    sentiment="Pos: "+ str(pcount) +" Neg: "+ str(ncount)
    return temp[0]

# %%
articles["Sentiments"]=articles["NormTokens"].apply(lambda x:GetSentiment(x))

# %%
articles.head()
# Out:
#                                             articles  \
# 0  No wonder Jose Mourinho is worried about the s...
# 1  Premier League clubs are facing a last minute ...
# 2  The new Premier League season has finally arri...
# 3  Manchester United have held talks with Bayern ...
# 4  Everton have agreed a £28.5million fee for Bar...
#
#                                               Tokens  \
# 0  [No, wonder, Jose, Mourinho, is, worried, abou...
# 1  [Premier, League, clubs, are, facing, a, last,...
# 2  [The, new, Premier, League, season, has, final...
# 3  [Manchester, United, have, held, talks, with, ...
# 4  [Everton, have, agreed, a, £28.5million, fee, ...
#
#                                    MsgSentenceTokens  \
# 0  [No wonder Jose Mourinho is worried about the ...
# 1  [Premier League clubs are facing a last minute...
# 2  [The new Premier League season has finally arr...
# 3  [Manchester United have held talks with Bayern...
# 4  [Everton have agreed a £28.5million fee for Ba...
#
#                                           NormTokens  \
# 0  [no, wonder, jose, mourinho, is, worried, abou...
# 1  [premier, league, clubs, are, facing, a, last,...
# 2  [the, new, premier, league, season, has, final...
# 3  [manchester, united, have, held, talks, with, ...
# 4  [everton, have, agreed, a, £28.5million, fee, ...
#
#                                              POS_Msg  \
# 0  [(no, DT), (wonder, NN), (jose, NN), (mourinho...
# 1  [(premier, JJR), (league, NN), (clubs, NNS), (...
# 2  [(the, DT), (new, JJ), (premier, NN), (league,...
# 3  [(manchester, NN), (united, VBD), (have, VBP),...
# 4  [(everton, NN), (have, VBP), (agreed, VBN), (a...
#
#                                          POS_Msg_Uni  \
# 0  [(no, DET), (wonder, NOUN), (jose, NOUN), (mou...
# 1  [(premier, ADJ), (league, NOUN), (clubs, NOUN)...
# 2  [(the, DET), (new, ADJ), (premier, NOUN), (lea...
# 3  [(manchester, NOUN), (united, VERB), (have, VE...
# 4  [(everton, NOUN), (have, VERB), (agreed, VERB)...
#
#                                            POS_Msg_2  \
# 0  [wonder, jose, mourinho, is, worried, start, s...
# 1  [league, clubs, are, facing, minute, panic, ai...
# 2  [premier, league, season, has, arrived, comes,...
# 3  [manchester, united, have, held, talks, munich...
# 4  [everton, have, agreed, £28.5million, fee, def...
#
#                                              Chunked  Sentiments  Sentiments2
# 0  [(no, DT), (wonder, NN), (jose, NN), (mourinho...         1.0         -1.0
# 1  [(premier, JJR), (league, NN), (clubs, NNS), (...        -1.0         -1.0
# 2  [(the, DT), (new, JJ), (premier, NN), (league,...         0.0         -1.0
# 3  [(manchester, NN), (united, VBD), (have, VBP),...        -1.0          1.0
# 4  [(everton, NN), (have, VBP), (agreed, VBN), (a...         1.0          1.0

# %%
def stem_words(words):
    """Stem words in list of tokenized words"""
    stemmer = LancasterStemmer()
    stems = []
    for word in words:
        stem = stemmer.stem(word)
        stems.append(stem)
    return stems

# %%
def lemmatize_verbs(words):
    """Lemmatize verbs in list of tokenized words"""
    lemmatizer = WordNetLemmatizer()
    lemmas = []
    for word in words:
        lemma = lemmatizer.lemmatize(word, pos='v')
        lemmas.append(lemma)
    return lemmas

# %%
def stem_and_lemmatize(words):
    stems = stem_words(words)
    lemmas = lemmatize_verbs(words)
    return stems, lemmas

# %%
articles['stems'] = articles["NormTokens"].apply(lambda x: stem_words(x))

# %%
articles['lemmas'] = articles["NormTokens"].apply(lambda x: lemmatize_verbs(x))

# %%
articles["articles"]=final_list

# %%
articles["lemmas"][0]
# Out:
# ['wonder',
#  'jose',
#  'mourinho',
#  'worry',
#  'start',
#  'new',
#  'season',
#  'four',
#  'days',
#  'go',
#  'kick',
#  'old',
#  'trafford',
#  'still',
#  'wait',
#  'real',
#  'manchester',
#  'unite',
#  'turn',
#  'strange',
#  'disjoint',
#  'weeks',
#  'mourinho',
#  'players',
#  'show',
#  'complete',
#  'preseason',
#  'muggy',
#  'night',
#  'munich',
#  'evidence',
#  'whatever',
#  'team',
#  'unite',
#  'put',
#  'friday',
#  'night',
#  'struggle',
#  'overcome',
#  'leicester',
#  'never',
#  'mind',
#  'challenge',
#  'manchester',
#  'city',
#  'dominance',
#  'premier',
#  'league',
#  'bayern',
#  'munich',
#  '343',
#  'neuer',
#  'kimmich',
#  'rudy',
#  '72',
#  'sule',
#  'hummels',
#  'boateng',
#  '46',
#  'alaba',
#  'bernat',
#  '56',
#  'martinez',
#  'robben',
#  'muller',
#  'thiago',
#  'rafinha',
#  '60',
#  'ribery',
#  'gnabry',
#  'sub',
#  'ulreich',
#  'hoffmann',
#  'lewandowski',
#  'boateng',
#  'goretzka',
#  'coman',
#  'mai',
#  'zylla',
#  'franzke',
#  'book',
#  'boateng',
#  'scorer',
#  'martinez',
#  '59',
#  'man',
#  'utd',
#  '433',
#  'de',
#  'gea',
#  'grant',
#  '78',
#  'darmian',
#  'jones',
#  '65',
#  'bailly',
#  'smalling',
#  '51',
#  'lindelof',
#  'tuanzebe',
#  '78',
#  'shaw',
#  'mitchell',
#  '78',
#  'herrera',
#  'garner',
#  '81',
#  'pereira',
#  'fred',
#  'chong',
#  '78',
#  'mata',
#  'mctominay',
#  '65',
#  'rashford',
#  'fosumensah',
#  '65',
#  'sanchez',
#  'sub',
#  'greenwood',
#  'referee',
#  'robert',
#  'hartmann',
#  'city',
#  'give',
#  'another',
#  'demonstration',
#  'wembley',
#  'unite',
#  'look',
#  'every',
#  'bite',
#  'team',
#  'come',
#  'together',
#  'drip',
#  'drabs',
#  'marcus',
#  'rashford',
#  'return',
#  'hour',
#  'officially',
#  'inherit',
#  'no10',
#  'shirt',
#  'vacate',
#  'zlatan',
#  'ibrahimovic',
#  'phil',
#  'jones',
#  'victor',
#  'lindelof',
#  'also',
#  'play',
#  'first',
#  'time',
#  'since',
#  'world',
#  'cup',
#  'still',
#  'paul',
#  'pogba',
#  'romelu',
#  'lukaku',
#  'jesse',
#  'lingard',
#  'ashley',
#  'young',
#  'marouane',
#  'fellaini',
#  'nemanja',
#  'matic',
#  'antonio',
#  'valencia',
#  'injure',
#  'anthony',
#  'martial',
#  'marcos',
#  'rojo',
#  'leave',
#  'home',
#  'unite',
#  'fly',
#  'germany',
#  'cast',
#  'doubt',
#  'futures',
#  'old',
#  'trafford',
#  'eric',
#  'bailly',
#  'limp',
#  'early',
#  'second',
#  'half',
#  'new',
#  'centrehalf',
#  'remain',
#  'priority',
#  'mourinho',
#  'bank',
#  'unite',
#  'chief',
#  'ed',
#  'woodward',
#  'deliver',
#  'one',
#  'unite',
#  'report',
#  'step',
#  'interest',
#  'harry',
#  'maguire',
#  '75million',
#  'bid',
#  'sunday',
#  'night',
#  'leicester',
#  'continue',
#  'resist',
#  'understand',
#  'jerome',
#  'boateng',
#  'halftime',
#  'substitute',
#  'bayern',
#  'emerge',
#  'another',
#  'strong',
#  'possibility',
#  'even',
#  'though',
#  'would',
#  'cost',
#  '50m',
#  'turn',
#  '30',
#  'next',
#  'month',
#  'ask',
#  'boateng',
#  'mourinho',
#  'say',
#  'ceo',
#  'know',
#  'want',
#  'quite',
#  'long',
#  'time',
#  'know',
#  'try',
#  'best',
#  'still',
#  'days',
#  'wait',
#  'see',
#  'happen',
#  'otherwise',
#  'unite',
#  'boss',
#  'prepare',
#  'make',
#  'players',
#  'available',
#  'leicester',
#  'unlucky',
#  'get',
#  'friday',
#  'game',
#  'monday',
#  'tuesday',
#  'wednesday',
#  'thursday',
#  'enough',
#  'add',
#  'organise',
#  'week',
#  'way',
#  'arrive',
#  'fresh',
#  'friday',
#  'friday',
#  'start',
#  'premier',
#  'league',
#  'play',
#  'point',
#  'friday',
#  'players',
#  'time',
#  'cry',
#  'players',
#  'go',
#  'friday',
#  'go',
#  'best',
#  'possible',
#  'team',
#  'unite',
#  'look',
#  'anything',
#  'finish',
#  'article',
#  'hard',
#  'see',
#  'click',
#  'gear',
#  'four',
#  'days',
#  'fragment',
#  'preparation',
#  'cosh',
#  'throughout',
#  'david',
#  'de',
#  'gea',
#  'make',
#  'first',
#  'half',
#  'save',
#  'thiago',
#  'alcantara',
#  'serge',
#  'gnabry',
#  'however',
#  'beat',
#  '59th',
#  'minute',
#  'javi',
#  'martinez',
#  'rise',
#  'score',
#  'glance',
#  'header',
#  'thiago',
#  'corner',
#  'timely',
#  'reminder',
#  'perhaps',
#  'unite',
#  'need',
#  'upgrade',
#  'central',
#  'defence',
#  'manuel',
#  'neuer',
#  'single',
#  'save',
#  'make',
#  'mourinho',
#  'end',
#  'game',
#  'send',
#  'kid',
#  'thirdchoice',
#  'keeper',
#  'lee',
#  'grant',
#  'maybe',
#  'message',
#  'woodward',
#  'strain',
#  'relationship',
#  'could',
#  'deteriorate',
#  'even',
#  'nt',
#  'new',
#  'addition',
#  'door',
#  '5pm',
#  'thursday',
#  'peter',
#  'kenyon',
#  'former',
#  'unite',
#  'chelsea',
#  'chief',
#  'executive',
#  'play',
#  'key',
#  'role',
#  'mourinho',
#  'appointment',
#  'stamford',
#  'bridge',
#  '2004',
#  'claim',
#  'sunday',
#  '55yearold',
#  'portuguese',
#  'coach',
#  'still',
#  'make',
#  'work',
#  'warn',
#  'unite',
#  'bigger',
#  'anybody',
#  'bigger',
#  'individual',
#  'always',
#  'mantra']

# %%
nltk.chunk.conllstr2tree(str(articles["POS_Msg"][0]), chunk_types=['NP']).draw()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-133-9e777f71c078> in <module>()
# ----> 1 nltk.chunk.conllstr2tree(str(articles["POS_Msg"][0]), chunk_types=['NP']).draw()
#
# D:\product\Anaconda\lib\site-packages\nltk\chunk\util.py in conllstr2tree(s, chunk_types, root_label)
#     385         match = _LINE_RE.match(line)
#     386         if match is None:
# --> 387             raise ValueError('Error on line {:d}'.format(lineno))
#     388         (word, tag, state, chunk_type) = match.groups()
#     389
#
# ValueError: Error on line 0

# %%
sid.polarity_scores

# %%
# Out:
# '[(\'no\', \'DT\'), (\'wonder\', \'NN\'), (\'jose\', \'NN\'), (\'mourinho\', \'NN\'), (\'is\', \'VBZ\'), (\'worried\', \'VBN\'), (\'about\', \'IN\'), (\'the\', \'DT\'), (\'start\', \'NN\'), (\'of\', \'IN\'), (\'the\', \'DT\'), (\'new\', \'JJ\'), (\'season\', \'NN\'), (\'.\', \'.\'), (\'four\', \'CD\'), (\'days\', \'NNS\'), (\'to\', \'TO\'), (\'go\', \'VB\'), (\'until\', \'IN\'), (\'it\', \'PRP\'), (\'kicks\', \'VBZ\'), (\'off\', \'RP\'), (\'at\', \'IN\'), (\'old\', \'JJ\'), (\'trafford\', \'NN\'), (\'and\', \'CC\'), (\'he\', \'PRP\'), (\'is\', \'VBZ\'), (\'still\', \'RB\'), (\'waiting\', \'VBG\'), (\'for\', \'IN\'), (\'the\', \'DT\'), (\'real\', \'JJ\'), (\'manchester\', \'NN\'), (\'united\', \'VBD\'), (\'to\', \'TO\'), (\'turn\', \'VB\'), (\'up\', \'RP\'), (\'.\', \'.\'), (\'this\', \'DT\'), (\'has\', \'VBZ\'), (\'been\', \'VBN\'), (\'a\', \'DT\'), (\'strange\', \'JJ\'), (\',\', \',\'), (\'disjointed\', \'VBD\'), (\'few\', \'JJ\'), (\'weeks\', \'NNS\'), (\'for\', \'IN\'), (\'mourinho\', \'NN\'), (\'and\', \'CC\'), (\'his\', \'PRP$\'), (\'players\', \'NNS\'), (\',\', \',\'), (\'and\', \'CC\'), (\'it\', \'PRP\'), (\'showed\', \'VBD\'), (\'as\', \'IN\'), (\'they\', \'PRP\'), (\'completed\', \'VBD\'), (\'their\', \'PRP$\'), (\'pre-season\', \'NN\'), (\'on\', \'IN\'), (\'a\', \'DT\'), (\'muggy\', \'JJ\'), (\'night\', \'NN\'), (\'in\', \'IN\'), (\'munich\', \'NN\'), (\'.\', \'.\'), (\'on\', \'IN\'), (\'this\', \'DT\'), (\'evidence\', \'NN\'), (\',\', \',\'), (\'whatever\', \'WDT\'), (\'team\', \'NN\'), (\'united\', \'VBD\'), (\'put\', \'VBD\'), (\'out\', \'RP\'), (\'on\', \'IN\'), (\'friday\', \'JJ\'), (\'night\', \'NN\'), (\'will\', \'MD\'), (\'struggle\', \'VB\'), (\'to\', \'TO\'), (\'overcome\', \'VB\'), (\'leicester\', \'NN\'), (\'never\', \'RB\'), (\'mind\', \'VBP\'), (\'challenge\', \'JJ\'), (\'manchester\', \'NNP\'), (\'city\', \'NN\'), ("\'s", \'POS\'), (\'dominance\', \'NN\'), (\'of\', \'IN\'), (\'the\', \'DT\'), (\'premier\', \'NN\'), (\'league\', \'NN\'), (\'.\', \'.\'), (\'bayern\', \'JJ\'), (\'munich\', \'JJ\'), (\'(\', \'(\'), (\'3-4-3\', \'JJ\'), (\')\', \')\'), (\':\', \':\'), (\'neuer\', \'NN\'), (\';\', \':\'), (\'kimmich\', \'CC\'), (\'(\', \'(\'), (\'rudy\', \'VB\'), (\'72\', \'CD\'), (\')\', \')\'), (\',\', \',\'), (\'sule\', \'NN\'), (\',\', \',\'), (\'hummels\', \'NNS\'), (\'(\', \'(\'), (\'boateng\', \'IN\'), (\'46\', \'CD\'), (\')\', \')\'), (\',\', \',\'), (\'alaba\', \'FW\'), (\'(\', \'(\'), (\'bernat\', \'IN\'), (\'56\', \'CD\'), (\')\', \')\'), (\';\', \':\'), (\'martinez\', \'CC\'), (\';\', \':\'), (\'robben\', \'NN\'), (\',\', \',\'), (\'muller\', \'NN\'), (\',\', \',\'), (\'thiago\', \'NN\'), (\'(\', \'(\'), (\'rafinha\', \'VB\'), (\'60\', \'CD\'), (\')\', \')\'), (\',\', \',\'), (\'ribery\', \'NN\'), (\';\', \':\'), (\'gnabry\', \'NN\'), (\'.\', \'.\'), (\'subs\', \'NNS\'), (\':\', \':\'), (\'ulreich\', \'JJ\'), (\',\', \',\'), (\'hoffmann\', \'NN\'), (\',\', \',\'), (\'lewandowski\', \'NN\'), (\',\', \',\'), (\'boateng\', \'NN\'), (\',\', \',\'), (\'goretzka\', \'NN\'), (\',\', \',\'), (\'coman\', \'NN\'), (\',\', \',\'), (\'mai\', \'NN\'), (\',\', \',\'), (\'zylla\', \'NN\'), (\',\', \',\'), (\'franzke\', \'NN\'), (\'.\', \'.\'), (\'booked\', \'VBN\'), (\':\', \':\'), (\'boateng\', \'JJ\'), (\'scorer\', \'NN\'), (\':\', \':\'), (\'martinez\', \'NN\'), (\'59\', \'CD\'), (\'man\', \'NN\'), (\'utd\', \'NN\'), (\'(\', \'(\'), (\'4-3-3\', \'JJ\'), (\')\', \')\'), (\':\', \':\'), (\'de\', \'FW\'), (\'gea\', \'FW\'), (\'(\', \'(\'), (\'grant\', \'VB\'), (\'78\', \'CD\'), (\')\', \')\'), (\';\', \':\'), (\'darmian\', \'JJ\'), (\'(\', \'(\'), (\'jones\', \'NNS\'), (\'65\', \'CD\'), (\')\', \')\'), (\',\', \',\'), (\'bailly\', \'RB\'), (\'(\', \'(\'), (\'smalling\', \'VBG\'), (\'51\', \'CD\'), (\')\', \')\'), (\',\', \',\'), (\'lindelof\', \'FW\'), (\'(\', \'(\'), (\'tuanzebe\', \'IN\'), (\'78\', \'CD\'), (\')\', \')\'), (\',\', \',\'), (\'shaw\', \'FW\'), (\'(\', \'(\'), (\'mitchell\', \'VB\'), (\'78\', \' ...

# %%
sid.polarity_scores(articles["articles"][15])
# Out:
# {'neg': 0.081, 'neu': 0.843, 'pos': 0.076, 'compound': -0.3248}
